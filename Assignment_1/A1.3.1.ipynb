# %% [markdown]
# # 3 Edge detection

# %% [markdown]
# ## 3.1 Sobel edge detector

# %% [markdown]
# ### 3.1.1 Effect of sharpening on edge detection

# %% [markdown]
# ##### 3.1.1.1 - 3.1.1.2

# %%
# creating an image
import numpy as np
import cv2
import matplotlib.pyplot as plt

# store image path
img_path = "./rice.png"
# load the image as grayscale
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# apply 15x15 Sobel filters to the intensity channel
I_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
I_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)
# compute sobel Magnitude/Phase
I_m = cv2.magnitude(I_x, I_y)
I_p = cv2.phase(I_x, I_y)

# display images
plt.figure(figsize=(20, 20))
plt.subplot(131), plt.imshow(img, cmap="gray")
plt.title("Image"), plt.xticks([]), plt.yticks([])
plt.subplot(132), plt.imshow(I_x, cmap="gray")
plt.title("I_x"), plt.xticks([]), plt.yticks([])
plt.subplot(133), plt.imshow(I_y, cmap="gray")
plt.title("I_y"), plt.xticks([]), plt.yticks([])

plt.figure(figsize=(20, 20))
plt.subplot(121), plt.imshow(I_m, cmap="gray")
plt.title("I_m"), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(I_p, cmap="gray")
plt.title("I_p"), plt.xticks([]), plt.yticks([])
plt.show()

# filter image using 5x5 Gaussian, the std is calculated automatically
res1 = cv2.GaussianBlur(I_x, (5,5), 0)
res2 = cv2.GaussianBlur(I_y, (5,5), 0)


# plot
plt.figure(figsize=(20, 20))
plt.subplot(121), plt.imshow(res1, cmap="gray")
plt.title("I_x Gaussian"), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(res2, cmap="gray")
plt.title("I_y Gaussian"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# 3.1.3
# creating an image
import numpy as np
import cv2
import matplotlib.pyplot as plt

# store image path
img_path = "./rice.png"
# load the image as grayscale
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# apply 15x15 Sobel filters to the intensity channel
I_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
I_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)
# compute sobel Magnitude/Phase
I_m = cv2.magnitude(I_x, I_y)

THRESH_1 = 200
THRESH_2 = 800

# same operation without loops
ret, img_thresh_1 = cv2.threshold(I_m, THRESH_1, 255, cv2.THRESH_BINARY)
ret, img_thresh_2 = cv2.threshold(I_m, THRESH_2, 255, cv2.THRESH_BINARY)

# display images
plt.figure(figsize=(20, 20))
plt.subplot(121), plt.imshow(img_thresh_1, cmap="gray")
plt.title("Thresholded 200"), plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(img_thresh_2, cmap="gray")
plt.title("Thresholded 800"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# 3.1.2.1
THRESH = 1500

# store image path
img_path = "./rice.png"
# load the image as grayscale
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# apply 5x5 Sobel filters to the intensity channel
I_x = cv2.Sobel(img, cv2.CV_64F, 1, 0, ksize=5)
I_y = cv2.Sobel(img, cv2.CV_64F, 0, 1, ksize=5)
I_m = cv2.magnitude(I_x, I_y)
# same operation without loops
ret, img_thresh_1 = cv2.threshold(I_m, THRESH, 255, cv2.THRESH_BINARY)
# display images
plt.figure(figsize=(30, 30))
plt.subplot(411), plt.imshow(I_x, cmap="gray")
plt.title("I_x"), plt.xticks([]), plt.yticks([])
plt.subplot(412), plt.imshow(I_y, cmap="gray")
plt.title("I_y"), plt.xticks([]), plt.yticks([])
plt.subplot(413), plt.imshow(img_thresh_1, cmap="gray")
plt.title("Thresholded 1500"), plt.xticks([]), plt.yticks([])
plt.subplot(414), plt.imshow(img, cmap="gray")
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# 3.1.2.2
# store image path
img_path = "./cameraman.jpg"
# load the image as grayscale
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

denoised_img = cv2.GaussianBlur(img, (5,5), 0)

# apply 5x5 Sobel filters to the intensity channel
I_x = cv2.Sobel(denoised_img, cv2.CV_64F, 1, 0, ksize=5)
I_y = cv2.Sobel(denoised_img, cv2.CV_64F, 0, 1, ksize=5)

I_m = cv2.magnitude(I_x, I_y)
# same operation without loops
ret, img_thresh_denoised = cv2.threshold(I_m, THRESH, 255, cv2.THRESH_BINARY)

# display images
plt.figure(figsize=(30, 30))
plt.subplot(511), plt.imshow(denoised_img, cmap="gray")
plt.title("Denoised image"), plt.xticks([]), plt.yticks([])
plt.subplot(512), plt.imshow(I_x, cmap="gray")
plt.title("I_x"), plt.xticks([]), plt.yticks([])
plt.subplot(513), plt.imshow(I_y, cmap="gray")
plt.title("I_y"), plt.xticks([]), plt.yticks([])
plt.subplot(514), plt.imshow(img_thresh_denoised, cmap="gray")
plt.title("Thresholded 1500"), plt.xticks([]), plt.yticks([])
plt.subplot(515), plt.imshow(img, cmap="gray")
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.show()
