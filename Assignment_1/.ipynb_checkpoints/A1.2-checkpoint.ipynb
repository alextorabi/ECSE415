# %%
# 2.1.1 and 2.1.2
# creating an image
import numpy as np
import cv2
import matplotlib.pyplot as plt

# load image
image_path = "./Circles.png" # use your own image path
img = cv2.imread(image_path)

noise_image_path = "./Circles_gauss.png"
noise_imag = cv2.imread(noise_image_path)

# filter image using 5x5 Gaussian, the std is calculated automatically
res1 = cv2.GaussianBlur(noise_imag, (5,5), 0)


# create a box filter
# filter the image
kernel = np.ones((5,5), np.float32)/(5*5)
# print("kernel:", kernel)
res2 = cv2.blur(noise_imag, (5,5))

# convert from BGR to RGB for displaying
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
res1 = cv2.cvtColor(res1, cv2.COLOR_BGR2RGB)
res2 = cv2.cvtColor(res2, cv2.COLOR_BGR2RGB)
noise_imag = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
diff1 = cv2.PSNR(res1, img)
diff2 = cv2.PSNR(res2, img)
print(diff1 + '\n')
print(diff2 + '\n')


# display images
plt.figure(figsize=(15, 15))
plt.subplot(141), plt.imshow(img)
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.subplot(142), plt.imshow(res1)
plt.title("5x5 Gaussian"), plt.xticks([]), plt.yticks([])
plt.subplot(143), plt.imshow(res2)
plt.title("Box filter"), plt.xticks([]), plt.yticks([])
plt.subplot(144), plt.imshow(noise_imag)
plt.title("Circles gauss"), plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# 38.86688147449975

# %%
# load image
image_path = "./Circles.png" # use your own image path
img = cv2.imread(image_path)

noise_image_path = "./Circles_gauss.png"
noise_imag = cv2.imread(noise_image_path)

# filter image using 5x5 Gaussian
res1 = cv2.GaussianBlur(noise_imag, (9,9), 0)

# create a box filter
# filter the image
kernel = np.ones((9,9), np.float32)/(9*9)
# print("kernel:", kernel)
res2 = cv2.blur(noise_imag, (9,9))

# convert from BGR to RGB for displaying
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
res1 = cv2.cvtColor(res1, cv2.COLOR_BGR2RGB)
res2 = cv2.cvtColor(res2, cv2.COLOR_BGR2RGB)
noise_imag = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.subplot(141), plt.imshow(img)
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.subplot(142), plt.imshow(res1)
plt.title("9x9 Gaussian"), plt.xticks([]), plt.yticks([])
plt.subplot(143), plt.imshow(res2)
plt.title("Box filter"), plt.xticks([]), plt.yticks([])
plt.subplot(144), plt.imshow(noise_imag)
plt.title("Circles gauss"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# load image
image_path = "./Circles.png" # use your own image path
img = cv2.imread(image_path)

noise_image_path = "./Circles_gauss.png"
noise_imag = cv2.imread(noise_image_path)

# filter image using 5x5 Gaussian
res1 = cv2.GaussianBlur(noise_imag, (13,13), 0)

# create a box filter
# filter the image
kernel = np.ones((13,13), np.float32)/(13*13)
# print("kernel:", kernel)
res2 = cv2.blur(noise_imag, (13,13))

# convert from BGR to RGB for displaying
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
res1 = cv2.cvtColor(res1, cv2.COLOR_BGR2RGB)
res2 = cv2.cvtColor(res2, cv2.COLOR_BGR2RGB)
noise_imag = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.subplot(141), plt.imshow(img)
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.subplot(142), plt.imshow(res1)
plt.title("13x13 Gaussian"), plt.xticks([]), plt.yticks([])
plt.subplot(143), plt.imshow(res2)
plt.title("Box filter"), plt.xticks([]), plt.yticks([])
plt.subplot(144), plt.imshow(noise_imag)
plt.title("Circles gauss"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# load image
image_path = "./Circles.png" # use your own image path
img = cv2.imread(image_path)

noise_image_path = "./Circles_gauss.png"
noise_imag = cv2.imread(noise_image_path)

# filter image using 5x5 Gaussian, the std is calculated automatically
res1 = cv2.GaussianBlur(noise_imag, (5,5), 0)

# filter image using 5x5 median filter
res2 = cv2.medianBlur(noise_imag, 5)

# convert from BGR to RGB for displaying
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
res1 = cv2.cvtColor(res1, cv2.COLOR_BGR2RGB)
res2 = cv2.cvtColor(res2, cv2.COLOR_BGR2RGB)
noise_imag = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.subplot(141), plt.imshow(img)
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.subplot(142), plt.imshow(res1)
plt.title("5x5 Gaussian"), plt.xticks([]), plt.yticks([])
plt.subplot(143), plt.imshow(res2)
plt.title("Median Filter"), plt.xticks([]), plt.yticks([])
plt.subplot(144), plt.imshow(noise_imag)
plt.title("Circles gauss"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# load image
image_path = "./Circles.png" # use your own image path
img = cv2.imread(image_path)

noise_image_path = "./Circles_gauss.png"
noise_imag = cv2.imread(noise_image_path)

# filter image using 5x5 Gaussian, the std is calculated automatically
res1 = cv2.GaussianBlur(noise_imag, (9,9), 0)

# filter image using 5x5 median filter
res2 = cv2.medianBlur(noise_imag, 9)

# convert from BGR to RGB for displaying
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
res1 = cv2.cvtColor(res1, cv2.COLOR_BGR2RGB)
res2 = cv2.cvtColor(res2, cv2.COLOR_BGR2RGB)
noise_imag = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.subplot(141), plt.imshow(img)
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.subplot(142), plt.imshow(res1)
plt.title("9x9 Gaussian"), plt.xticks([]), plt.yticks([])
plt.subplot(143), plt.imshow(res2)
plt.title("Median Filter"), plt.xticks([]), plt.yticks([])
plt.subplot(144), plt.imshow(noise_imag)
plt.title("Circles gauss"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# load image
image_path = "./Circles.png" # use your own image path
img = cv2.imread(image_path)

noise_image_path = "./Circles_gauss.png"
noise_imag = cv2.imread(noise_image_path)

# filter image using 5x5 Gaussian, the std is calculated automatically
res1 = cv2.GaussianBlur(noise_imag, (13,13), 0)

# filter image using 5x5 median filter
res2 = cv2.medianBlur(noise_imag, 13)

# convert from BGR to RGB for displaying
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
res1 = cv2.cvtColor(res1, cv2.COLOR_BGR2RGB)
res2 = cv2.cvtColor(res2, cv2.COLOR_BGR2RGB)
noise_imag = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.subplot(141), plt.imshow(img)
plt.title("Original"), plt.xticks([]), plt.yticks([])
plt.subplot(142), plt.imshow(res1)
plt.title("13x13 Gaussian"), plt.xticks([]), plt.yticks([])
plt.subplot(143), plt.imshow(res2)
plt.title("Median Filter"), plt.xticks([]), plt.yticks([])
plt.subplot(144), plt.imshow(noise_imag)
plt.title("Circles gauss"), plt.xticks([]), plt.yticks([])
plt.show()
