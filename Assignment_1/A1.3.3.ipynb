# %%
# 3.3.2
# creating an image
import numpy as np
import cv2
import matplotlib.pyplot as plt


# store image path
dop_img_path = "./dolphin.jpg"
# load image as gray-scaled
dop_img = cv2.imread(dop_img_path, cv2.IMREAD_GRAYSCALE)

# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5, 5), 0)

# compute Canny edges
dop_I_edge = cv2.Canny(dop_img, 10, 100)
#I_edge = cv2.Canny(img, 50, 100)

# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(dop_I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)

# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (5,5), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (9,9), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 10, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 30, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 100)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 150)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
# blur image before-hand
dop_img = cv2.GaussianBlur(dop_img, (13,13), 0)
# compute Canny edges
I_edge = cv2.Canny(dop_img, 50, 200)
# display images
plt.figure(figsize=(10, 10))
plt.subplot(111), plt.imshow(I_edge, cmap="gray")
plt.title("I_edge"), plt.xticks([]), plt.yticks([])
plt.show()
